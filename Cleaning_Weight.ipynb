# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Loading the dataset 'Weight.Log'

# %%
weight_df = pd.read_csv("Weight.csv")

# %% [markdown]
# ### Check structure, missing values, duplicates and data types

# %%
weight_df.head()
# Out:
#     Customer_ID                Date Day_of_Week     Date.1      Time  \
# 0  1.503960e+09   5/2/2016 23:59:59      Monday   5/2/2016  23:59:59
# 1  1.927972e+09   4/13/2016 1:08:52   Wednesday  4/13/2016   1:08:52
# 2  2.873213e+09  4/21/2016 23:59:59    Thursday  4/21/2016  23:59:59
# 3  2.873213e+09  5/12/2016 23:59:59    Thursday  5/12/2016  23:59:59
# 4  4.319704e+09  4/17/2016 23:59:59      Sunday  4/17/2016  23:59:59
#
#   Weight_Kg Weight_Pounds  Fat    BMI Is_Manual_Report  Manual_Report  \
# 0     52.60        115.96   22  22.65             True            1.0
# 1    133.50        294.32  NaN  47.54            False            2.0
# 2     56.70        125.00  NaN  21.45             True            1.0
# 3     57.30        126.32  NaN  21.69             True            1.0
# 4     72.40        159.61   25  27.45             True            1.0
#
#          Log_Id
# 0  1.462234e+12
# 1  1.460510e+12
# 2  1.461283e+12
# 3  1.463098e+12
# 4  1.460938e+12

# %%
weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       66 non-null     float64
#  1   Date              66 non-null     object
#  2   Day_of_Week       66 non-null     object
#  3   Date.1            66 non-null     object
#  4   Time              66 non-null     object
#  5   Weight_Kg         67 non-null     object
#  6   Weight_Pounds     67 non-null     object
#  7   Fat               4 non-null      object
#  8   BMI               68 non-null     object
#  9   Is_Manual_Report  66 non-null     object
#  10  Manual_Report     66 non-null     float64
#  11  Log_Id            66 non-null     float64
# dtypes: float64(3), object(9)
# memory usage: 15.0+ KB

# %%
weight_df.describe()
# Out:
#         Customer_ID  Manual_Report        Log_Id
# count  6.600000e+01      66.000000  6.600000e+01
# mean   7.092696e+09       1.393939  1.461763e+12
# std    1.840903e+09       0.492366  7.860126e+08
# min    1.503960e+09       1.000000  1.460444e+12
# 25%    6.962181e+09       1.000000  1.461064e+12
# 50%    6.962181e+09       1.000000  1.461771e+12
# 75%    8.877689e+09       2.000000  1.462391e+12
# max    8.877689e+09       2.000000  1.463098e+12

# %%
# Inspect columns
weight_df.columns
# Out:
# Index(['Customer_ID', 'Date', 'Day_of_Week', 'Date.1', 'Time', 'Weight_Kg',
#        'Weight_Pounds', 'Fat', 'BMI', 'Is_Manual_Report', 'Manual_Report',
#        'Log_Id'],
#       dtype='object')

# %%
# Column cleaning and standardization
weight_df.columns = (
    weight_df.columns
    .str.strip()                   # removes invisible spaces
    .str.lower()                   # makes everything lowercase
    .str.replace(" ", "_")         # replaces spaces with underscores
    .str.replace(".", "_", regex=False)  # replaces literal periods with underscores
)    

# Verifying the changes
weight_df.columns
# Out:
# Index(['customer_id', 'date', 'day_of_week', 'date_1', 'time', 'weight_kg',
#        'weight_pounds', 'fat', 'bmi', 'is_manual_report', 'manual_report',
#        'log_id'],
#       dtype='object')

# %% [markdown]
# ### Converting 'date' column from object into datetime format

# %%
weight_df['date'] = pd.to_datetime(weight_df['date'])

#Verifying the changes
weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       66 non-null     float64
#  1   date              66 non-null     datetime64[ns]
#  2   day_of_week       66 non-null     object
#  3   date_1            66 non-null     object
#  4   time              66 non-null     object
#  5   weight_kg         67 non-null     object
#  6   weight_pounds     67 non-null     object
#  7   fat               4 non-null      object
#  8   bmi               68 non-null     object
#  9   is_manual_report  66 non-null     object
#  10  manual_report     66 non-null     float64
#  11  log_id            66 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 15.0+ KB

# %% [markdown]
# ### Extracting date only column

# %%
weight_df['date'] = weight_df['date'].dt.date

# %%
# Verifying the changes
weight_df.columns
# Out:
# Index(['customer_id', 'date', 'day_of_week', 'date_1', 'time', 'weight_kg',
#        'weight_pounds', 'fat', 'bmi', 'is_manual_report', 'manual_report',
#        'log_id'],
#       dtype='object')

# %% [markdown]
# ### Converting Weight and BMI columns to Numeric before rounding

# %%
weight_df['weight_kg'] = pd.to_numeric(weight_df['weight_kg'], errors='coerce')
weight_df['weight_pounds'] = pd.to_numeric(weight_df['weight_pounds'], errors='coerce')
weight_df['bmi'] = pd.to_numeric(weight_df['bmi'], errors='coerce')
weight_df['fat'] = pd.to_numeric(weight_df['fat'], errors='coerce')

# Verifying the changes
weight_df.dtypes
# Out:
# customer_id         float64
# date                 object
# day_of_week          object
# date_1               object
# time                 object
# weight_kg           float64
# weight_pounds       float64
# fat                 float64
# bmi                 float64
# is_manual_report     object
# manual_report       float64
# log_id              float64
# dtype: object

# %% [markdown]
# ### Dropping redundant columns

# %%
weight_df = weight_df.drop(columns=['date_1', 'time', 'manual_report', 'day_of_week'])

# %%
# Verifying the changes
weight_df.columns
# Out:
# Index(['customer_id', 'date', 'weight_kg', 'weight_pounds', 'fat', 'bmi',
#        'is_manual_report', 'log_id'],
#       dtype='object')

# %% [markdown]
# ### Handle missing values

# %%
# Since we do not have additional data to fill in missing values in Fat column, we will keep it as it is for now.
# Total numnber of missing values in each column
weight_df.isna().sum()
# Out:
# customer_id          93
# date                 93
# weight_kg            93
# weight_pounds        93
# fat                 157
# bmi                  93
# is_manual_report     93
# log_id               93
# dtype: int64

# %% [markdown]
# ### Rounding off Weight and BMI values

# %%
weight_df['weight_kg'] = weight_df['weight_kg'].round(1)
weight_df['weight_pounds'] = weight_df['weight_pounds'].round(1)
weight_df['bmi'] = weight_df['bmi'].round(1)


# Verifying the changes
weight_df.head()
# Out:
#     customer_id        date  weight_kg  weight_pounds   fat   bmi  \
# 0  1.503960e+09  2016-05-02       52.6          116.0  22.0  22.6
# 1  1.927972e+09  2016-04-13      133.5          294.3   NaN  47.5
# 2  2.873213e+09  2016-04-21       56.7          125.0   NaN  21.4
# 3  2.873213e+09  2016-05-12       57.3          126.3   NaN  21.7
# 4  4.319704e+09  2016-04-17       72.4          159.6  25.0  27.4
#
#   is_manual_report        log_id
# 0             True  1.462234e+12
# 1            False  1.460510e+12
# 2             True  1.461283e+12
# 3             True  1.463098e+12
# 4             True  1.460938e+12

# %% [markdown]
# ### Remove Duplicates

# %%
weight_df = weight_df.drop_duplicates()

# %% [markdown]
# ### Final look at the cleaned dataset

# %%
weight_df.head()
# Out:
#     customer_id        date  weight_kg  weight_pounds   fat   bmi  \
# 0  1.503960e+09  2016-05-02       52.6          116.0  22.0  22.6
# 1  1.927972e+09  2016-04-13      133.5          294.3   NaN  47.5
# 2  2.873213e+09  2016-04-21       56.7          125.0   NaN  21.4
# 3  2.873213e+09  2016-05-12       57.3          126.3   NaN  21.7
# 4  4.319704e+09  2016-04-17       72.4          159.6  25.0  27.4
#
#   is_manual_report        log_id
# 0             True  1.462234e+12
# 1            False  1.460510e+12
# 2             True  1.461283e+12
# 3             True  1.463098e+12
# 4             True  1.460938e+12

# %% [markdown]
# ### Saving the cleaned dataset

# %%
# Saving the cleaned dataset
weight_df.to_csv("Cleaned_Weight.csv", index=False)
